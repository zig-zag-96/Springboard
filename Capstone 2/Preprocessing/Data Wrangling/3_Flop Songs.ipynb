# %% [markdown]
# In this notebook I will wrangle the data for the flop songs (non-hits). I will do this using a random name generator that I will feed to a search function. I will order the results by album release date and then pick a song whose URI is NOT in the billboard dataset.
#
# There are two conditions:
# 1. The song cannot be part of the billboard hit data
# 2. The song needs to have been released in the same time period (2001-2020)
#
# Let's get started.

# %% [markdown]
# I have downloaded a a list of random english words from MIT that is stored in a csv called Random_Words.csv.
#
# I will randomly pick words from this list that will be the basis for the tracknames of the flop songs

# %%
# Import Modules

import pandas as pd
import random
import datetime
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from random import sample
import math

# %%
#import csvs with billboard data and random word list
random_words = pd.read_csv('Random_Words.csv')
billboard = pd.read_csv('BillboardWithURI.csv')

# %%
random_words
# Out:
#        words
# 0          a
# 1         aa
# 2        aaa
# 3      aaron
# 4         ab
# ...      ...
# 9995    zope
# 9996  zshops
# 9997      zu
# 9998     zum
# 9999     zus
#
# [10000 rows x 1 columns]

# %%
# get api key from your .env file

import os

from dotenv import load_dotenv

from pathlib import Path

 

dotenv_path = Path('./SpotifyAPIKey.env')

load_dotenv(dotenv_path=dotenv_path)

 

#load_dotenv()

API_CLIENT_ID = os.getenv('SPOTIFY_CLIENT_ID')
API_CLIENT_SECRET = os.getenv('SPOTIFY_CLIENT_SECRET')
 
print(API_CLIENT_ID)
print(API_CLIENT_SECRET)
# Out:
# 3f7295d24d8041688f494196baeb607f
# 42896ec37b22446680c5a485858a4843

# %% [markdown]
# Methodology:
#
#
# create function to get the random uri from the random word. then get the title and artist from that random uri. store it in a list. the function should look back over the list to make sure there are no matching uris.

# %%
URIs = []

# %%
for i in range(2001):
    word = random_words.sample(i, replace= True, random_state=42)

type(word)
# Out:
# pandas.core.frame.DataFrame

# %%
#Get Flop song URIs

def get_uri(rand_word):
    client_credentials_manager = SpotifyClientCredentials(client_id=API_CLIENT_ID,client_secret=API_CLIENT_SECRET)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    track = sp.search(q="track:" +f"{rand_word} + year: 2001-2020",type='track',limit=10)
    result = track['tracks']['items']
    
    for items in result:
        uri = items['id']
        dict1 = items['album'] 
        if uri not in billboard['URI']:
            URIs.append(uri)

# %%
get_uri('cheese')

# %%
URIs
# Out:
# []

# %%
for lab,row in word.iterrows():
    get_uri(row['words'])

# %%
URIs
# Out:
# ['3bT8vIfhau8ktNjo7scr9X',
#  '2iiCDhPr51If2XCDQJJ0nC',
#  '7EOGIqRUHjsnDFoerUgBWY',
#  '0qIJPc8EF7EATnXbtNaVZP',
#  '0kz35q6rsNDB6d6XHNfLO4',
#  '1Jo3yW1tWC4JSjGS2s2DPy',
#  '5o7dxKpuojix9gzcNE5DtE',
#  '5tN5Y4VcX8K6k0WXpPI7LV',
#  '37PoYGJMxkKsSRukMoU3Rc',
#  '6DsP6w8eeyl1Hhef6NBVwC',
#  '53BZ6XygAoubR5DU5w38Vq',
#  '4VMiNOpnjRwSCwmHaUfOMM',
#  '6MLsahMK3VvH9NUwXOktdS',
#  '5qMcCmuqBDvE6iVxeuqunC',
#  '4otQJBpb8okSeykALR3eCH',
#  '4OmlsAT8r4q9vPFBvfYgyZ',
#  '59M6uElNZGBp8oukOPteNl',
#  '0Ks6oG5Ic7X8gKtn34yi3E',
#  '5MnhJTEb01EQmeF3CgmnE3',
#  '5orJsNWnDIy52oZ2Ax4eHM',
#  '2u54HNQamwFuOMLSuhSRom',
#  '2ag0hixCwLjj9Gi5Z44hbO',
#  '07ePHsQ0SopWrnCbNjNC2D',
#  '7FwkoTz8Ic8C5YaE9XXGIU',
#  '4ffYbqNOSn01NHOmQGJEKT',
#  '4xs3eeuZb1WofrjlUp65QP',
#  '31n0kYnWG4Xlyzb5Cy2HxU',
#  '5v6BCEvqciaOrfxvF4pcEQ',
#  '3pvTTAniXOLKWWtXn5sViP',
#  '6g1M36yrsmxPwPuLdFZcy1',
#  '5Mm2CJzNRiICC5MWRWQnBo',
#  '2ZgJ3fxDrGSi3VKe84YDAe',
#  '15tpxASJbTcAAfezvJfvuj',
#  '6XchxkE3WuUovo0O50u7SX',
#  '2onuiR30fndsiwnY4FR8wi',
#  '4LvXQDy62I5MD6JEBZcDXS',
#  '3Kil8DEZI7WS6hN2RXltfl',
#  '6rgmHos0kapmml7VwqSrXS',
#  '5QAhmroRA03WZ3KIu345lq',
#  '3Bj1fTJC5zIqAUybuCyRl2',
#  '4yL4ruTYw4vT8EHVYhTBF3',
#  '50lyujwzaTSSnLee11LpgV',
#  '6sKnY09AuwKO0YkdJZ9r69',
#  '3lZKYg23T9sylDOY2B89N3',
#  '6wKn2KjwGymkexYeBjEGAF',
#  '41YPbtutzcVQ8dPR1heFcg',
#  '19lUCCRU3l2zreiQWi76rs',
#  '0dcnyGQ9MXoiIS4zAdb3Eo',
#  '1C2F7NlsuMEcP2fgFFfl9E',
#  '07LSykC5sRN3DYbtMJxJTH',
#  '30QR0ndUdiiMQMA9g1PGCm',
#  '3GCdLUSnKSMJhs4Tj6CV3s',
#  '1otG6j1WHNvl9WgXLWkHTo',
#  '3afkJSKX0EAMsJXTZnDXXJ',
#  '4Ce37cRWvM1vIGGynKcs22',
#  '2N3U8uTYhjX2KwGT0pf5x0',
#  '4bEcoz1OcfMgUbp2ft8ieQ',
#  '3oGbHF3Kdwf3AsRCbBjUxu',
#  '0VF7YLIxSQKyNiFL3X6MmN',
#  '4H7WNRErSbONkM06blBoGc',
#  '4ZYNW3hBYf93iPVsSbrhzD',
#  '1cW1olYUkXD5UDmd97oqVp',
#  '788ggtDwaQxCGWskEskCDK',
#  '6Hkr6dnbF7Q7B0DNTPXRGK',
#  '36BEGpoi2xsGM3OIiNYSZ7',
#  '30meMjsopkEzClhqI6rYh1',
#  '2qKzYQyeGde6wez2YQLHFO',
#  '5esP6wtH8JbeQKSp9c23mQ',
#  '6sS1hqKjT680bW6eAa84PR',
#  '27g8BYt4QEL2FaCyKSN7rg',
#  '4lhUxx9a9EUxRf7p4TG9Zl',
#  '0mAte245jD75WAAKhnPDZe',
#  '7Hs8Xy7LaRIHoC3sdvn7A1',
#  '31hEdYRATORu0wsh3uX4yx',
#  '7AShdOZgOhxdE2yR0zxehM',
#  '0jAHpWGEF6CpyiTroZMeGb',
#  '0mN3Z1xXnIGss3VGuGuW9C',
#  '1zZFaEBTjg2vOPlWChcxUy',
#  '4CUk14Rfx1ZxFH9TXs1WB8',
#  '2TEp5yK6LDUHGYJ6C66Kmv',
#  '6SN81d9vLbPYP9lmcSv3xt',
#  '6qowqr8A5fBseAMUXal8PE',
#  '6UmIsyIcjyvmd1kkebIu9G',
#  '2pGfYSpCpASZN8z4t5CvdN',
#  '2J0XEIsz5obUqzZ27jjny1',
#  '1zGBVv20PEfcxOScO1FEUl',
#  '76uH82GW81kVkIrEAiSEx8',
#  '4UAA8s7tprm4kPegFL8VJt',
#  '0GYqX2Xo4lLwgegpAXd7rv',
#  '77QUjT9pTZkKGZCE3fZD7K',
#  '19I3dX6fxCAWuvgCbvgxoN',
#  '2UYEhdYBIb3umP2n6y5x3o',
#  '53qpVd2xZYAjciuhQeWHde',
#  '08VageUMSg2YiL4gvZM5Rj',
#  '2w0Y7YUO4gH0cEZvOLzvoA',
#  '5B2tdIpqhDMWv6Hdqnpqkw',
#  '2UGpJBjQZnQtuXO868p8EH',
#  '05nII9He1eKhHh9RKJCthM',
#  '5a7lyRUyJxXpWqJLE4VUtR',
#  '0BB8SC9JMxUcntDgnnWcKM',
#  '2MRI9yUwAePS5pwrgqYW8J',
#  '1aLxKiwmqtwKDgnlLJTv0D',
#  '2JFzLcCQ7FLY2OkP1wb8LN',
#  '57aSzx3UaArVYdGxg2IUYD',
#  '1JT3ghZCfHpqP6M52jm9dM',
#  '1mWCI4rxvYF9ELliQg1iUg',
#  '2aKxfUQg9dhvgm7Yt9Lc7Q',
#  '1DWjJOjb5OEiOxEQwCfASf',
#  '6qfIwUb7F1cdZUq7ECiEPx',
#  '1eumDcFTsoLPEN31viUhkt',
#  '3AF6JW5zzVmSkQWIKMVYqh',
#  '3zLeZbjtoS5dS8qXt3274Y',
#  '06DMGZ3FVrU1rnFrDvcfzx',
#  '4DzQPw4z8y8ZcJ6EmEz843',
#  '0lM2gOkbRojJhxjG93TzkK',
#  '5p8qTEHVIFrpAEsVyt0Hw6',
#  '39K1aI0kx4aw9hxa9gwE2V',
#  '1XryAGbNwT76LI5wysXtza',
#  '4QkqtRwugZqJSDxFokfAmx',
#  '1x3iLC07Cp5rV3rjeZyyJm',
#  '48OcpPMo9u0V0n4hfrNnKC',
#  '7hD1ieUbiE0xyQkdCR7WSN',
#  '24xWnYn6IenBjsqIPCpDX6',
#  '4Ww39sgnlPIxoib5sfk5pN',
#  '7LdBi9ptmrcYlhE1mxprjd',
#  '0XmLRP1GkjjRrdIx0G75Dj',
#  '4goKsrzIKnlOelVz5aiZyI',
#  '0bXJUOzIPWoAVSBMFczcr2',
#  '6c5YmpkzmCBjCuerCPU6ng',
#  '4bHhE7fbL8jU6niJzqM8AX',
#  '3RW16XAZ9N9uz5CUCnBqdQ',
#  '1SC65EG1YqStvPMxfk9df8',
#  '0UqzGyeOB6Ajj5dsh08klF',
#  '5rg914Yfweb8iCsBgA7knZ',
#  '7otIrlN4FS2yjS8dCJSI5U',
#  '5w4pEMdQIuLmvkQXUgD8rF',
#  '0CioIaUQ2Gi8i0CCViIQ7d',
#  '6BDu7lsmjaWlzZXRtDThra',
#  '3TXoSy2JIx7uWXmPfFozJK',
#  '576ESmEeHt0NE9SxHn1Qvm',
#  '6xmXkzy9nR1hjknzGC5fUJ',
#  '7ADFqIjMLrhRXyWoxeEhGf',
#  '40dSOCGECiDOhY6GHzbQSw',
#  '3lm3FtlMhtha5oAywLwRt7',
#  '6zEQFZO3QNAoKnbxy4GIT4',
#  '6QRXuf3AtNXowhKAgHK5gb',
#  '0boGn0O8E9T13qR7p63U3A',
#  '3ggUkAHrPakwVkXbKofIJH',
#  '1fe62lFcDW8lLDXzWkF7KB',
#  '0zdyi6udgDLzfy1b8eLvfE',
#  '3I46QgYOht122TzwB1onR2',
#  '634YxRIDFwUehMhbmRU5sF',
#  '2GEg5svSo6Hr9OECuQJYfZ',
#  '1YtCpIIl3OnHcLIyaKQS6z',
#  '4KVeA4HUZhFwWImftRAtth',
#  '4ynvyu6lfZhXEEUSno0Fod',
#  '0pk1hxhJLBSZZ5RKBhcwOa',
#  '2BiCH1atqXX1OXOtL0PKHS',
#  '2ECN9udpHeB6tCk9FKM97V',
#  '6Tn9J7LOj5CuytqzORpkrz',
#  '06OGd6FldeaOpOaH2mkjM8',
#  '3fiCSQSEJrAP2NvPEuQnKm',
#  '3iEUxTn1IJQ6qqzWVaynNv',
#  '3Jg6r94oJ09wvQMmGEV3pf',
#  '54JXsOoVIJ1w738Oze7z6u',
#  '14P7NXsAZZRxVkM7x3D0e5',
#  '0Ov5Q7TgPnkptLNQQqN2kk',
#  '1T6dQI8z0iHcbn1LwmppIE',
#  '6FwXdk8hoWVKKt73unEmh9',
#  '5EnBQCfJYACOVgQVdWserv',
#  '5BHLmcP9q9T0uoZzk4FsRF',
#  '425SpXfrrDxvbvTUjQXwTI',
#  '23kjj565tVtuTu5qF6YAa5',
#  '4euv9j4cBV7v8V8QLv2Oiq',
#  '358ICau4oVfRBA9tqHzWqh',
#  '6Goot5XLzT0iP5RBDtOLYU',
#  '1pKMnBqpCILOu4ckAggjSo',
#  '7udukMiui8MJ9Uf88qeySi',
#  '7jhKAjGy30tt5YTHqCvd5X',
#  '7rtZEncB5nRRJ1P6pBaXGr',
#  '67HVAtbGifsRSsuO06VYp9',
#  '2Np2HmP13IwNBHjV7cqKWs',
#  '2Im4pJvX0rcczER0IXRifp',
#  '0h26QouCAsw4ibCAA7PScp',
#  '2DxIZkSAjEJoq88MRtLbF1',
#  '0LcxxsQKSGYjT3k3zwjfhH',
#  '0AsA1SBO5yJt819yVnVi3S',
#  '1g9jDtTfKBLdsqjV6E50C4',
#  '5zjCN94WcXgp0UscWMlkvn',
#  '7uPaX419HAwGnvIbL4FS91',
#  '62qnxCems7scAGJmBJdDXO',
#  '1MAxEw6vR1LpblEo2yljce',
#  '2liVQGw5kjT1kdBuIhTk1T',
#  '2SFAd5NatVuUhEo6ncqYnL',
#  '3urkBlnfYMrZtcd8zOEmEO',
#  '3LTBRu6qgnYSSMUSK4oN04',
#  '19bH1CEHOUHiNSj2nYjCSO',
#  '4cavxOTlbywuSAtaH7E5Yw',
#  '1SGUMa3NOmTl9WFPC72OIB',
#  '4geCb1GUKB64GnbiCks2pC',
#  '29Kzcy6h9gW5MVWgdNbhkD',
#  '3ss7116xRLMcx0RQtByeI3',
#  '1BD9cwuCUgaNazndbPU63G',
#  '7BHiQN9vM2VQc9QtqZzhyx',
#  '6ppJrxE8S0cdPtVWRmnJ6u',
#  '5JEjNu9VD8pii0baATtkRT',
#  '10QDtqF1LXlcgEiAa1qyIk',
#  '1vrZaKabzPgoQ8HolOZABf',
#  '2LdWi7bPHr2NSWukgNvbHs',
#  '61SP5WrQuayWGZRvQyQLc0',
#  '3xGqMbDUuceW3SpMpwVjYV',
#  '5hFGk5CMh0EuULkNdNzgIX',
#  '16SWvs4zbz9tR8eFWPylWI',
#  '0U1dkW9FEwiGU1pLoFf2AN',
#  '5130x1JPI0cDjeN873XMRf',
#  '4cpChSsBwdEQJZu4m6KmvK',
#  '2HuxgJJanT4xSx0QEPMwvP',
#  '4bp6RxihAhMI7ayaP1ZEFJ',
#  '5vHIUKufiBXXpUCg4WVEly',
#  '7Dz9jfprHKpw5IHccAMHG0',
#  '0hRRcF4dAQ060juzSqSRV4',
#  '1I0T6O8xalgpfpE9uYoSCA',
#  '0KMyuNwf7QOVpcqr8gUuND',
#  '0HZye7hPuToL16Gd9kKpZj',
#  '6WQRISp8eiX6VMDam70sRY',
#  '5Gj7TabsK0sn1bU1Jk7OjQ',
#  '3L545updZMVxAsaYV6K8Z9',
#  '7IL8PSVwLOJxqYne6azxQv',
#  '7x8dCjCr0x6x2lXKujYD34',
#  '2fKPwiW1FJLH3JbB1DmR0K',
#  '588ROs3NuPqlPSYpIuitKS',
#  '4VzhdfRpM2sQjhzwYWjd30',
#  '4WdopfTdSd0nCLropjhsgH',
#  '7oW5YZZVeesParmVY7gx6s',
#  '1OxL1FWSEd7QmJoWLRP2NO',
#  '2k2MprlqkmDMKKOOWGREzW',
#  '57k31DtQNtvf2R8DpX5h6H',
#  '40JwuoG6avq9q9e4HYS7Qs',
#  '3etV6yY8m86Xcypax2UeNV',
#  '0yrNbLtZYBnrdhc9Eb6yt0',
#  '2MUJARwiEN4gz2tsHlNmRv',
#  '6oy3jXIeabezGNOlfw604z',
#  '7w6OGS3EayDdpMLEpfczxA',
#  '2nqeIxcE7qYQNJL79Cpl8e',
#  '2321GKuIArDb8llKz7wwdo',
#  '28kOLyrr0Pxd6njK9R0IpS',
#  '1f120PFzot73ifUUNjmIMq',
#  '0khal3xvTwIdCaEt5Igd1D',
#  '1iKIeXDaOkUJ6oiRRPcy78',
#  '4B6i7UULFLm4XH5LsQeyq4',
#  '6ZihHwEXlAY67ZMqnJdBpU',
#  '0oeWaDCu8fCbyCUi7BJoAu',
#  '6VN79rWMKySWxiec4VFNfN',
#  '246ton97bgCFoFWGbQnsTg',
#  '4lEfNHOWCz2E6tfyHjwoNV',
#  '4xAu4mIbsTsw0tLUyMnwh2',
#  '3bLfWceUlKeficBHMtlm35',
#  '4BmMT7mmksdHbYk4F8mr8v',
#  '3Tts9HEMtCDijXMJYWYTr7',
#  '4QS7ENkPrgRMpfybuo5aXu',
#  '2otSI9aQeDfV3w1Fdw34px',
#  '6Zos4X6y1eM1dT0dEw7VK6',
#  '6tAb75hY5NidMfbpI6427y',
#  '0d26ReOTZaf4DmBluJLJPi',
#  '7mFOO2gma3JosAOpv2dbyB',
#  '2PeAqtas69RljDB8GW6d1j',
#  '51bwChuoablcgmmSjvwe8Y',
#  '5GJq4DKoRTo3NUjiASJZFO',
#  '008BspjuJpmAPCRi7fWbOY',
#  '3Qt1wrcMPSXXxqeidsSsGb',
#  '7vhD3xirsnmyYTGtNMc1Ph',
#  '5DRiHotwkZFkFVRuUdwpib',
#  '4UyV4tTTJQXJC5Wu56mrMK',
#  '4zojZbmwsIYoclDvSkSqUi',
#  '2x9BJRQmha0JH3rU6Snpsz',
#  '0d6cQvE2RqPS9Mgl3Lcfbo',
#  '4X5f3vT8MRuXF68pfjNte5',
#  '51rXHuKN8Loc4sUlKPODgH',
#  '4iVD0fTHGxV9JWloujsL3s',
#  '0dbTQYW3Ad1FTzIA9t90E8',
#  '2RPbEp0DyBVlkRvvYKopO7',
#  '7LE1K0lZyRFZjSlrnm7lfD',
#  '77UjLW8j5UAGAGVGhR5oUK',
#  '1eLSF6HfrRA0AsNmTkUlKx',
#  '1eLU27PPFxBhbp1CBjPh9J',
#  '3DcL8FXLA9iKwqnyj9POLt',
#  '0UwsTR4qFd0kjJviMtVBIs',
#  '15Bj2mnFiEdDEoOcnLvEcX',
#  '3pHST9YijKAzBJlIRS7R47',
#  '6OaY4KX8ENVogGeMcDrvMx',
#  '7w7oyRRI2FkOvZHFvw0hid',
#  '4lLRzGh5OuTuive3PRtPyq',
#  '2zAWZ4iMwnBZ3s3HdTx1Rx',
#  '70Z3IxXGp6e5lpinwhkwui',
#  '6Np7zjvzQXdyCTlP7HAhmd',
#  '1tx5hzKkBHyi2vz33L0d3H',
#  '320PoUyeENCT4sm7eJTOeI',
#  '5yKoI9bQUFkyQMtxJ5tBJo',
#  '5UbOxJBgXw07YVS0g2xLjD',
#  '6FfVqf9009gt1JQuiYV6oO',
#  '3FDMsBnFm36BQZwEqgMMKt',
#  '3yfMhADkLzxo43j4eNVYOX',
#  '1xJC9sSCH28KAbZhHI0i15',
#  '0l5idlJEHNuk0og5t5j8nX',
#  '6buQETVRsFKSwOHQWTzRnF',
#  '71oQ6Pl0zo8K7xmeCekBfr',
#  '5XeP5eQReAZSub4fRUWs3E',
#  '0VrLFGs6hMfChr0vvlpkDO',
#  '3nFkrJmmaup9hVjk9t2JXM',
#  '0q8HjW4ISYQtd6gRpIz1Oz',
#  '0VseEzl053xxp00BuvfxQv',
#  '514OHGWnOlhZmgAFA9svHo',
#  '5AztYoWPngLyMK9rfxGmeR',
#  '7BPGWHyhovUTn5K2Oa7qpa',
#  '1XbgEw0eKHKl9rYOdwbr4o',
#  '6JlauGkfmUGfHrNwNceOxO',
#  '5cHTNQUvokJTlxEBRnsjMa',
#  '65vl3XfT46fYODMoxuhs9O',
#  '0JQphHutd5MMPqZ6wZyKwL',
#  '7rhNUVCnEQJkvwW6rKeUDM',
#  '4ALpZDM9VeQsKy9UdllhZz',
#  '2tOhC2piVa1QQanFaPncQg',
#  '7CuLj1HCn3SZbQNo0vKbFD',
#  '3mmdj7jdF1pR54WwpQIbIZ',
#  '4vLSp3F1EMsFDXQhJuElcE',
#  '2WEfAwIXpxi5PoUVGw4h9Z',
#  '5RYTpsSI7op7UZznXWqhIP',
#  '1N5k3HUb2FcwNjvZRSAFDK',
#  '5pmEPJ1DnCLqQkUT4B2wAp',
#  '5jjsDgg3JhTcutthudLi7Q',
#  '5vtGYY6ZWl5n3izcVJ7n49',
#  '0BOwtCEi23eZjCevJxgCAB',
#  '3tFqfwkboCGIxZ8ZHntowb',
#  '5WrcC3XofANRypKdj5kLtt',
#  '0gQUUHFR9xA4BdDSz24TgD',
#  '5xpTC8cRiXJNB0zMrOXPAe',
#  '5G9qKplB5e4lIpSncwKWVE',
#  '4EtKV9VxLbL6wgeQjiPm4r',
#  '0VJc0VM2TJWp6wi4szBFaw',
#  '3PpuDg0ZVPviHuljT3R087',
#  '4SenxwCmSCIXfklUvmXyNc',
#  '6avZSgjOfUEzByTKMIrWzQ',
#  '2Wx0ZVHSrk73sXDX9ejDv1',
#  '2Ocrrp9yiHYy08Qw0Ht4eo',
#  '4lWeAYtwmyzgDlJp44whZQ',
#  '7gYob6ua0ybAU8ZtvRaYL1',
#  '7jQO8NAyErvzM5QjXQAoYd',
#  '7J91kCQx1S7R2Sh3Fsgg2A',
#  '0lfOyju9K7KplOW9W8x6Zh',
#  '0CZ0sJGEeKwH3PIQZ83gtS',
#  '0Slje4iHF1rPiaPaQToMnm',
#  '0VgAWoNjTkKSBkOOd3PJgW',
#  '0LauOlStNRBCcWts2nBACm',
#  '2CRz1dAppk9CKHEXFlUDHl',
#  '7uf3KzPTOrvTPCeDMKmk6h',
#  '2KvfxjXiBfwAYXCY3P1Bz1',
#  '62hG3J548LhVeEWh0H4zB4',
#  '3UgMRxho2yO0QsArLHvb8g',
#  '6G12jNuFIRI2840HLH9xtq',
#  '75fodJ81TiBgEEQvBSNOA9',
#  '38o7HO34mcozYKj7dcnlxA',
#  '3dDnvi8uqS6X4wwjoq2uUN',
#  '68j2rZF6Y5r7LL2ap5h6nO',
#  '5Dxeuq3DaLU5fmpWCOpjBD',
#  '2F2i4rIAaPQV2oe262tTZx',
#  '52tQ2R5lWx81lUbSEUpBJo',
#  '5kH2p0KGZNZPr9XcJJLPAv',
#  '1VLtjHwRWOVJiE5Py7JxoQ',
#  '2u3hJqwkyVlgRkHR6AWboq',
#  '4i11n6N7xIBKsHvTBupusV',
#  '6i7zAdNhzUN2k1HcrBxPHG',
#  '2uiEqPjMmIJXOKplzsEASP',
#  '2eqDUxbd0JPEhNrJdPlHLs',
#  '7IZn95vTYrhHRbFmZsdD2A',
#  '41tl6xfIKib7fexaHudvV0',
#  '6fU55C7VdMSSkJ0ZGmX2Kg',
#  '6u0EAxf1OJTLS7CvInuNd7',
#  '6x7mz58HIWCTij1hwAmImH',
#  '7mdXDSUBrdVymRCMqclmtj',
#  '6gqJYtF7vrjtT9JzsQQSoy',
#  '1a7WZZZH7LzyvorhpOJFTe',
#  '1Xwh83YOFQARZ3QXscP123',
#  '5P45rIpV682KkvtZjZtuwB',
#  '6IS7RAH2yBYzOyqggWSDxm',
#  '4TkVE9FZudrKDdchZNTMqL',
#  '79oQb66jALYYKX1hn4qs4p',
#  '19u5pVvN3Ud0u3bPaq6Lnn',
#  '57M3x7GWQHGbaI6NgjWwr6',
#  '5nb0BEZqsmQYseSPJ932K8',
#  '26bn9OCVa4MW826HIIGNfr',
#  '2QJVLwQdk2aGdLEs0xp89R',
#  '137RYE5KTGp6kZz13empRa',
#  '09LpNxZ1KQvpA5xirKfXqf',
#  '3wwfXKfYHfllCC3bPdesKF',
#  '2FfafODHyfBL1JAoflhqVm',
#  '0OLGbL1kXA0QovG0Gn928g',
#  '7CS71TJxq6KCcGVOGRyasJ',
#  '1ENo588Js9RZUYgNzPnHTx',
#  '6pcHZIyS6pPFqDl0RE4ZMy',
#  '1zhvDrGXoMmhPgwBkwwImi',
#  '0XWLi9IG0mYwdcBFtUdhC8',
#  '0XhhtvR3BYqfg9JM1jM9Cb',
#  '5x72ol5TLUO0ymkQr4JuWB',
#  '3f4MjCmGeEjuJ9EhswsRpe',
#  '1ph7yHAVYzeq1MdcYBfAA8',
#  '497zOKCyTyQONJJnlHgsLp',
#  '1zjPf0FrnNyiIae9N4adOb',
#  '30H6pSDtuKhkNA4a6HIA1W',
#  '483v27PMHWBtPFyXQ3rElQ',
#  '7qPWOaZ7NuYgcFbDYc9EOo',
#  '6Tguhaf2uAe6OjRLsR2Tql',
#  '2MbdDtCv5LUVjYy9RuGTgC',
#  '5R8dQOPq8haW94K7mgERlO',
#  '5CFJRZRq6sdKKtRwNPWbYv',
#  '0ZLuW8uOXdFNWcI40C0OC2',
#  '3WQilym5Vi4ypxb70vx0eY',
#  '6MO2bfLHKykUgCChFdw91H',
#  '0fgZUSa7D7aVvv3GfO0A1n',
#  '11dxtPJKR4E0wlSr0A0t47',
#  '3Ddny34bFoYBb8dIGq5lwp',
#  '5WNYg3usc6H8N3MBEp4zVk',
#  '7sKChFvViJZ6FzQZwCuPqZ',
#  '4k2ix82xyGax7S8u6ODb6B',
#  '1ewuc6RHlQKZxyCrz6ovVS',
#  '6R2wys1ClpF8VEXAw4y4sO',
#  '5mTIzzIv60E2B034cZs70l',
#  '0DJaVpKuVyVjqKMd14Jh5N',
#  '7k7OMBXmnPDFlTA1j7MhYP',
#  '6i2wkaPVLm74OKXSPMF7t9',
#  '3M5hddYpQi34Vm9lZLYsf6',
#  '20dkebBtPR4AJ8vVos41Gw',
#  '5QWvi6JbRVpeFm1Db7ZMok',
#  '0EwxFHRLFLkc8hAouO0JNM',
#  '0fZNwKNbo0eYNoKEaE2bIa',
#  '5OnE0xB1fM4W7DLQ3vgLJR',
#  '6lprLc79G52VQPr2FPlnYL',
#  '4pcHkUiOAF4iDAXlvK66or',
#  '3YGlMRcbuaTaMdqaP74yIA',
#  '66QEF1ZhnHRPOKNoABqZDX',
#  '5MILUeRQvcaEONEOXzEFKU',
#  '5EnbxJsYyYwQhEIVEVPbNO',
#  '0nqxQ69fIXbNdmyYi6QTa0',
#  '71yNG8xlZwWPDOD9BO553V',
#  '1hwVIMnKAPCcj2JKJQxS12',
#  '45NVySJDlynv8cwePKQbBd',
#  '1YWncbyDaNuMR31BqbEfvA',
#  '4nM2LLElIXJh3hn19lgOLt',
#  '38S1cAkoABvybstWGHIMpO',
#  '4kVB3o9ibVwSva5rhw7wzC',
#  '1qBnUjjz4xQugyzFxvIS8h',
#  '2E3bw8LTr1FquW4yWy41L8',
#  '5rDjF3QocDYOO3K6vlTZkt',
#  '53ZyV2xdPQ4FzirkIrSK8B',
#  '3Sn5ap7v0rgTirrHiYv15Y',
#  '5HN3Al9lfCV9K2AtCAv8ne',
#  '7gkjFT2wmqagjfjshkYVtL',
#  '4oPOqtEXFvddwtoHG3H9Lq',
#  '6l0nnS7fX56dVcmL4j3VQq',
#  '4AUSfl0dJAd3qd4sWxwnyf',
#  '0ofpIIU9xGWMKHpCpsyvma',
#  '7v4rssfe07EbkTMMM7r95J',
#  '2TMHCnau1NeQ649KZNjwqa',
#  '4NXjeelACyyJ32H2UyZBld',
#  '5HyJUbwpXAwN9aCEmVwnLL',
#  '2VsdzC1lrEhiIyY4jiNdwE',
#  '2oej323a6ZP8VJiWGgI7PD',
#  '3i5Wctbn9mY31atnfrUMbN',
#  '6zGQjFU1gkMD18Ms93t2Lb',
#  '0bc0NusaKyZnVd6GMZAAW2',
#  '2vcJmxyOEKGdUY4EIyBdZj',
#  '15FHU1CWh3AsQVE2irab53',
#  '5SWKtbwwOS1KXkkIzR9BIG',
#  '7BsSfUzpdc6mIuvKaOiVMJ',
#  '0noJHZJMdJWmrfBsY3utdQ',
#  '43SrRLWCsmJE7WvdLOAMxA',
#  '4VLh8UaOqXOgesHOuEjJaA',
#  '507DGZ02rgMdn4cHS0p9vX',
#  '5EuOOf2TofSKE0IA93gRor',
#  '5vThTo3cNAntxYeOQKwgMl',
#  '6QAzHtAbwiJVzrOlvNzaIc',
#  '6XlfaXvDM55hr5wctH2mNd',
#  '0zL5lgFq4jQ0TNZ8K6QbK7',
#  '7wumsq89VLbMlbrrqHyWsT',
#  '6NDNqtZlZpfSuQCmvWbEvh',
#  '5G01lInrhwz3nIpfu5wHnO',
#  '0OHGQkR7q6N97Xl2xbpPwt',
#  '3Zka8SiinLs2oF2pBZkEVl',
#  '7DdC2jtdPnLAQC0NavKziF',
#  '4DF8N1ZlcWzejFLS7I6g4k',
#  '02lSwU5V6wmQpo4kVgpuJ1',
#  '3fYd2ahlXE0oH0ET4z09A1',
#  '4dG0jAbQFYD2QcOX7RhrDn',
#  '1trjf1zJ7aAXpPNJMFGK0y',
#  '3RkOSf7DTVkwxLQYmWFSGz',
#  '4CXkMlNX90V3EFZ5gvvuql',
#  '2jNDR35LMhjeSlD3e2J5AG',
#  '5DWokm0bDEb9aBKqO9wx4e',
#  '2YIQkTuJqb9oLhOmhPk3FP',
#  '4myxhjaQJSxzmim0lcWQnD',
#  '7sG62tiiUS69fb0iAXnvE2',
#  '1oEtKSSBOmCVXKCCJMfOFn',
#  '7mPfZ3p1YT62YDme7fqvsZ',
#  '0swrjb8oDKXVpWnvkmFPT4',
#  '3GRAmRiwbmyTYhzzBtUTuU',
#  '02RA2qizz9IMxeUlbg5TOI',
#  '03Aji6nA2bOepJewgLQUUa',
#  '3iT5FD6ZtGffWLyFgdEO65',
#  '7FgLx7CNxdhLMbHXQFdarp',
#  '2pNfUdUipHAODmv11pZtNk',
#  '59IyKRSgCwLyKS3e46TlYM',
#  '1nSSGcOnAk6LKSMInfzt52',
#  '4mAz6ncZQSDOBshABwyPOa',
#  '2WwRqNtaK77suweD6V2rIs',
#  '0iBDmq6oyXDiCzaeB8jiit',
#  '5WLOfLwNCh0I8HHbe4BDtm',
#  '08iMpPDCC9FHDIRWIx4oZN',
#  '61Ci6OR7mlpgMhzaX5JRSd',
#  '37vaNa0KFCyKTecvcCdtUk',
#  '5zTBw1Dw6OgEq9d4ize41y',
#  '7cqW2LGn277YeRb1McHp9i',
#  ...]

# %%
len(URIs)
# Out:
# 18920

# %%
#number of unique values in URI flop list and remove duplicates
URI_set = set(URIs)
len(URI_set)
# Out:
# 15706

# %%
#List of unique Flop song URIs

URI_list = list(URI_set)

# %%
# understanding how the sp.track function works
URI = '74atKkOasLOVzvqB6mYgga'
client_credentials_manager = SpotifyClientCredentials(client_id=API_CLIENT_ID,client_secret=API_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
track_name = sp.track(URI)

# %%
print(track_name)
# Out:
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6X1x82kppWZmDzlXXK3y3q'}, 'href': 'https://api.spotify.com/v1/albums/6X1x82kppWZmDzlXXK3y3q', 'id': '6X1x82kppWZmDzlXXK3y3q', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273c7ea04a9b455e3f68ef82550', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02c7ea04a9b455e3f68ef82550', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851c7ea04a9b455e3f68ef82550', 'width': 64}], 'name': 'Take Care (Deluxe)', 'release_date': '2011-11-15', 'release_date_precision': 'day', 'total_tracks': 19, 'type': 'album', 'uri': 'spotify:album:6X1x82kppWZmDzlXXK3y3q'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'}, 'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865', 'id': '55Aa2cqylxrFIXC767Z865', 'name': 'Lil Wayne', 'type': 'artist', 'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/74V3dE1a51skRkdII8y2C6'}, 'href': 'https://api.spotify.com/v1/artists/74V3dE1a51skRkdII8y2C6', 'id': '74V3dE1a51skRkdII8y2C6', 'name': 'André 3000', 'type': 'artist', 'uri': 'spotify:artist:74V3dE1a51skRkdII8y2C6'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR ...

# %%
def get_track_name (uri):
    client_credentials_manager = SpotifyClientCredentials(client_id=API_CLIENT_ID,client_secret=API_CLIENT_SECRET)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    tracks = sp.track(uri)
    
    track_name = tracks['name']
    return track_name

# %%
get_track_name('74atKkOasLOVzvqB6mYgga')
# Out:
# 'The Real Her'

# %%
def get_artist_name(uri):
    client_credentials_manager = SpotifyClientCredentials(client_id=API_CLIENT_ID,client_secret=API_CLIENT_SECRET)
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
    tracks = sp.track(uri)
    
    artist_name = tracks['artists']
    return artist_name[0]['name']

# %%
get_artist_name('74atKkOasLOVzvqB6mYgga')
# Out:
# 'Drake'

# %%
df= pd.DataFrame(URI_list)

# %%
df.head()
# Out:
#                         0
# 0  1o7S218Z4CG6IVCOudaPcT
# 1  0OAo7Std90wZ0D97aha6q4
# 2  0t4z0WaQomQqPONghWn8c2
# 3  1IyB9D543YtwYDIgSEURUW
# 4  06c4ArkPjDQbUnn9KAzk39

# %%
df = df.rename(columns={0 : 'URI'})

# %%
df.head()
# Out:
#                       URI
# 0  1o7S218Z4CG6IVCOudaPcT
# 1  0OAo7Std90wZ0D97aha6q4
# 2  0t4z0WaQomQqPONghWn8c2
# 3  1IyB9D543YtwYDIgSEURUW
# 4  06c4ArkPjDQbUnn9KAzk39

# %%
for lab,row in df.iterrows():
    df.loc[lab, 'Title'] = get_track_name(row['URI'])

# %%
df.head()
# Out:
#                       URI                                              Title
# 0  1o7S218Z4CG6IVCOudaPcT                      Lucy's Love (feat. Lil Wayne)
# 1  0OAo7Std90wZ0D97aha6q4  Chevy Music (feat. Don Cisco, Brown Boy & Ramero)
# 2  0t4z0WaQomQqPONghWn8c2                                     Me and Michael
# 3  1IyB9D543YtwYDIgSEURUW  Tenth Avenue Freeze-Out - Live at the Auditori...
# 4  06c4ArkPjDQbUnn9KAzk39           Hat Hair (feat. Sky The Pilot & Oweshin)

# %%
for lab,row in df.iterrows():
    df.loc[lab, 'Artist'] = get_artist_name(row['URI'])

# %%
df.head()
# Out:
#                       URI                                              Title  \
# 0  1o7S218Z4CG6IVCOudaPcT                      Lucy's Love (feat. Lil Wayne)
# 1  0OAo7Std90wZ0D97aha6q4  Chevy Music (feat. Don Cisco, Brown Boy & Ramero)
# 2  0t4z0WaQomQqPONghWn8c2                                     Me and Michael
# 3  1IyB9D543YtwYDIgSEURUW  Tenth Avenue Freeze-Out - Live at the Auditori...
# 4  06c4ArkPjDQbUnn9KAzk39           Hat Hair (feat. Sky The Pilot & Oweshin)
#
#               Artist
# 0                SiR
# 1          Baby Bash
# 2               MGMT
# 3  Bruce Springsteen
# 4             PEABOD

# %%
df= df[['Title', 'Artist', 'URI']]

# %%
df.head()
# Out:
#                                                Title             Artist  \
# 0                      Lucy's Love (feat. Lil Wayne)                SiR
# 1  Chevy Music (feat. Don Cisco, Brown Boy & Ramero)          Baby Bash
# 2                                     Me and Michael               MGMT
# 3  Tenth Avenue Freeze-Out - Live at the Auditori...  Bruce Springsteen
# 4           Hat Hair (feat. Sky The Pilot & Oweshin)             PEABOD
#
#                       URI
# 0  1o7S218Z4CG6IVCOudaPcT
# 1  0OAo7Std90wZ0D97aha6q4
# 2  0t4z0WaQomQqPONghWn8c2
# 3  1IyB9D543YtwYDIgSEURUW
# 4  06c4ArkPjDQbUnn9KAzk39

# %%
df.to_csv('flop_songs.csv')
